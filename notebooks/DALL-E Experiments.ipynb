# %%
# This gets rid of Jupyter's screen-realestate-wating-margin-of-gray.
#

from IPython.display import display, HTML, Markdown
display(HTML(
    '<style>'
        '#notebook { padding-top:10px !important; } ' 
        '.container { width:95% !important; } '
        '.end_space { min-height:5px !important; } '
    '</style>'
))
# Out:
# <style>#notebook { padding-top:10px !important; } .container { width:95% !important; } .end_space { min-height:5px !important; } </style>

# %% [markdown]
# # Customize Values

# %%
baseDir = "/Users/cjwang/Desktop"         # Directory where you store the images

imageWidth=256

# Variables for image generation
nImages = 4
# prompt = "an anime of a cute furry monster rolling on the floor laughing"
prompt = "a logo for a simple and deep IM app"

# Variables for generating variations
nVariations = 1
testFile = f"{baseDir}/SlavicGirl.png"    # The image that you want to generate variations with
croppedFile = f"{baseDir}/temp.png"       # DALL-E only accept squire images, so we crop the image into a squire and save it here

# %% [markdown]
# # Set up Environments
#
# Prepare the environment before the real work begins.

# %%
from PIL import Image
from IPython.display import Image as ipImage
from IPython.core.display import HTML

# %%
import os
import openai

accessKey = os.environ.get("OPENAI_KEY2")
openai.api_key = accessKey

orgId = os.environ.get("OPENAI_ORG")
openai.organization = orgId

# %% [markdown]
# # Generate Images

# %%
prompt="a girl kissing her dog in sunset on a beach"
imageWidth = 512
response = openai.Image.create(
  prompt=prompt,
  n=nImages,
  size=f"{imageWidth}x{imageWidth}"
)
imageUrl = [img["url"] for img in response['data']]

# %%
for url in imageUrl:
    print(url)
    dalleImg = ipImage(url=url)
    display(dalleImg)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-XxB7iHNrHRNUmmgeD74mniVB.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=SWS2j7kzTLGcoXDkDFaqzwi8FW9aSQ5sriPsORncRNY%3D
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-XxB7iHNrHRNUmmgeD74mniVB.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=SWS2j7kzTLGcoXDkDFaqzwi8FW9aSQ5sriPsORncRNY%3D"/>
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-spjho8v583iemC6AkfGNCJGd.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=GIPxTJHWhaFQkirrQ5Le5MfLY1pCNUFhPVA64O6b9Lw%3D
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-spjho8v583iemC6AkfGNCJGd.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=GIPxTJHWhaFQkirrQ5Le5MfLY1pCNUFhPVA64O6b9Lw%3D"/>
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-OWmAbXAhQKZeQiKAfIdQuNQ9.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=UyKl0G5gD4v/UwuL9itXKVil5MR9aqi4iPkkbnyE6Zc%3D
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-OWmAbXAhQKZeQiKAfIdQuNQ9.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=UyKl0G5gD4v/UwuL9itXKVil5MR9aqi4iPkkbnyE6Zc%3D"/>
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-B08SpouVVBytbpz4ORlsnVXD.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=8c6TYX9YPYNScA73uoN67zuTxwOvGLXFOL9A3hxIkVk%3D
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-FfhH4UEDDtqgXMnZVquB2jUw/user-ACthdXaj4sMAFZtlkvFmx03i/img-B08SpouVVBytbpz4ORlsnVXD.png?st=2022-12-10T01%3A23%3A02Z&se=2022-12-10T03%3A23%3A02Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-10T01%3A18%3A39Z&ske=2022-12-11T01%3A18%3A39Z&sks=b&skv=2021-08-06&sig=8c6TYX9YPYNScA73uoN67zuTxwOvGLXFOL9A3hxIkVk%3D"/>

# %% [markdown]
# # Generating Variations

# %%
im = Image.open(testFile)
width, height = im.size

# %%
length = min(width, height)
left = (width - length) // 2
right = left + length
top = (height - length) // 2
bottom = top + length
cropped = im.crop((left, top, right, bottom))
cropped.save(croppedFile)

# %%
display(ipImage(croppedFile))
print(width, length)
# Out:
# 966 966

# %%
# This doesn't work.  OpenAI contacted.  Waiting for response.
imageWidth = 256
response = openai.Image.create_variation(
  image=croppedFile,
  n=1,
  size=f"{imageWidth}x{imageWidth}"
)
image_url = response['data'][0]['url']
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In [24], line 3
#       1 # This doesn't work.  OpenAI contacted.  Waiting for response.
#       2 imageWidth = 256
# ----> 3 response = openai.Image.create_variation(
#       4   image=croppedFile,
#       5   n=1,
#       6   size=f"{imageWidth}x{imageWidth}"
#       7 )
#       8 image_url = response['data'][0]['url']
#
# File /usr/local/lib/python3.9/site-packages/openai/api_resources/image.py:51, in Image.create_variation(cls, image, api_key, api_base, api_type, api_version, organization, **params)
#      48     files.append((key, (None, value)))
#      49 files.append(("image", ("image", image, "application/octet-stream")))
# ---> 51 response, _, api_key = requestor.request("post", url, files=files)
#      53 return util.convert_to_openai_object(
#      54     response, api_key, api_version, organization
#      55 )
#
# File /usr/local/lib/python3.9/site-packages/openai/api_requestor.py:181, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     160 def request(
#     161     self,
#     162     method,
#    (...)
#     169     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     170 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     171     result = self.request_raw(
#     172         method.lower(),
#     173         url,
#    (...)
#     179         request_timeout=request_timeout,
#     180     )
# --> 181     resp, got_stream = self._interpret_response(result, stream)
#     182     return resp, got_stream, self.api_key
#
# File /usr/local/lib/python3.9/site-packages/openai/api_requestor.py:396, in APIRequestor._interpret_response(self, result, stream)
#     388     return (
#     389         self._interpret_response_line(
#     390             line, result.status_code, result.headers, stream=True
#     391         )
#     392         for line in parse_stream(result.iter_lines())
#     393     ), True
#     394 else:
#     395     return (
# --> 396         self._interpret_response_line(
#     397             result.content, result.status_code, result.headers, stream=False
#     398         ),
#     399         False,
#     400     )
#
# File /usr/local/lib/python3.9/site-packages/openai/api_requestor.py:429, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     427 stream_error = stream and "error" in resp.data
#     428 if stream_error or not 200 <= rcode < 300:
# --> 429     raise self.handle_error_response(
#     430         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     431     )
#     432 return resp
#
# InvalidRequestError: Uploaded image must be a PNG and less than 4 MB.
